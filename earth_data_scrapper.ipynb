# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshBagul1993/House-Price-Prection/blob/main/earth_data_scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Weather_API:
    
    def __init__ (self, keyword):
        self.keyword = keyword
        
    def json_print(self, obj):
        # create a formatted string of the Python JSON object
        with open('api_data.txt', 'w') as json_file:
            json.dump(obj, json_file)
        text = json.dumps(obj, sort_keys=True, indent=4)
        print(text)
        
    def create_dataframe(self, obj):
        
        # creating a dataframe from nested JSON objects
        FIELDS = ["source.id", "source.name", "author", "title", "description", "url", "urlToImage", "publishedAt", "content"]
        df = pd.json_normalize(obj['articles'])
        final_df = df[FIELDS]
        #final_df.set_index('source.id', inplace = True)
        display(final_df.head())

    
    def news_api(self):
        
        # Use the news-api to obtain articles published from
        url = ('https://newsapi.org/v2/everything?'
       'q={keyword}&'
       'apiKey=4e70cabb80884db08524a28ac33cdc1d'.format(keyword = self.keyword))
        
        
        response = requests.get(url)
        if (response.status_code == 200):
            print('API call successful!')
            json_response = response.json()
            if(len(json_response['articles']) == 0):
                print('No News Articles Found')
            else:
                
                # Print a String in Json Format
                self.json_print(json_response)
                
                
                
                # Create a pandas DataFrame
                self.create_dataframe(json_response)
                    
        else:
            print('Status code: ', response.status_code)

# %%
import requests
import json
import os
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup

class Web_Scraping:
    
    def __init__(self, location):
        self.location = location
        
    def selenium_webdriver(self):
        
        # Start the Driver
        driver = webdriver.Chrome(executable_path = r"C:\Users\Nilesh\.cache\selenium\chromedriver.exe")
        
        # Hit the url of NASA Earth Data website and wait for 15 seconds.
        url = ('https://earthdata.nasa.gov/search?q={location}'.format(location = self.location))
        driver.get(url)
        time.sleep(15)
        
        # Driver scrolls down 25 times to load the table.
        for i in range(0,30):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(10)
            
        # Fetch the webpage and store in a variable.
        webpage = driver.page_source
        
        # Parse the page using BeautifulSoup
        HTMLPage = BeautifulSoup(webpage, 'html.parser')
        
        titles = []
        description = []
        links = []

        for lists in HTMLPage.find_all(class_ = 'result'):
            if (lists.span.text != '' and len(lists.find_all('p')) != 0):
                titles.append(lists.span.text)
                description.append(lists.find('p', class_ = '').text)
                links.append(lists.find('p', class_ = 'search-link').text)
        
        # Create a DataFrame
        df = pd.DataFrame(list(zip(titles, description, links)),
               columns =['title', 'description', 'link'])
        
        display(df)
        
        # Store to csv file
        df.to_csv('ws.csv', sep=',', index=False,header=True)
        
        print('Web Scraping Successful!')
keyword = input('Enter Keyword to be searched: ').lower()
w_api = Weather_API(keyword)
w_api.news_api()

location = input('Enter Location: ').lower()
ws = Web_Scraping('India')
ws.selenium_webdriver()
# Out:
# Enter Keyword to be searched: mumbai
# API call successful!
# {
#     "articles": [
#         {
#             "author": "https://www.facebook.com/bbcnews",
#             "content": "The crew of an Indian airline tied an Italian woman to her seat during a flight after she allegedly misbehaved with them.\r\nThe woman, who was travelling on a Vistara flight from Abu Dhabi, was arrest\u2026 [+1786 chars]",
#             "description": "The Italian woman, who was arrested on a complaint by a crew member, has denied the allegations against her.",
#             "publishedAt": "2023-01-31T09:23:49Z",
#             "source": {
#                 "id": "bbc-news",
#                 "name": "BBC News"
#             },
#             "title": "Vistara: 'Unruly' passenger tied to seat in India flight",
#             "url": "https://www.bbc.co.uk/news/world-asia-india-64463181",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/18052/production/_128468389_vistara1.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 31 (Reuters) - Dollar bonds issued by entities of India's Adani Group continued to trade higher on Tuesday after a sharp dive in the past few sessions.\r\nThe bonds had sold off following a\u2026 [+558 chars]",
#             "description": "Dollar bonds issued by entities of India's Adani Group continued to trade higher on Tuesday after a sharp dive in the past few sessions.",
#             "publishedAt": "2023-01-31T10:00:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Dollar bonds of India's Adani Group continue to trade higher - Reuters",
#             "url": "https://www.reuters.com/markets/rates-bonds/dollar-bonds-indias-adani-group-continue-trade-higher-2023-01-31/",
#             "urlToImage": "https://www.reuters.com/resizer/JdNNuQGag_MApH8DGqQNG-DS4FY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SLC2FQMIZVJZNNCICPG5ESHEU4.jpg"
#         },
#         {
#             "author": "Karishma Luthria",
#             "content": "A cliche, overused in movies and young adult novels with Anglo protagonists, changed my life.\r\nIn June 2016, on a humid night in Mumbai, India, I was at a skate park-themed bar with colleagues from a\u2026 [+2395 chars]",
#             "description": "In this series, Guardian writers share the best advice they have received and how it has impacted their lives<ul><li>Get our weekend culture and lifestyle email</li></ul>A cliche, overused in movies and young adult novels with Anglo protagonists, changed my l\u2026",
#             "publishedAt": "2023-01-09T14:00:19Z",
#             "source": {
#                 "id": null,
#                 "name": "The Guardian"
#             },
#             "title": "My colleague said: \u2018Just be yourself.\u2019 It was the first time in my life anyone told me I could do that | Karishma Luthria",
#             "url": "https://www.theguardian.com/lifeandstyle/2023/jan/09/my-colleague-said-just-be-yourself-it-was-the-first-time-in-my-life-anyone-told-me-i-could-do-that",
#             "urlToImage": "https://i.guim.co.uk/img/media/7e07216caa44d1e20ed20aa6bd9bef904336926e/0_0_2500_1500/master/2500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctb3BpbmlvbnMucG5n&enable=upscale&s=b8e39d9148ba9111ece6187ef21fa1f2"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 11 (Reuters) - India will halt duty free imports of crude soyoil from April 1, the government said on Wednesday, as the world's biggest importer of vegetable oils tries to support local o\u2026 [+913 chars]",
#             "description": "India will halt duty free imports of crude soyoil from April 1, the government said on Wednesday, as the world's biggest importer of vegetable oils tries to support local oilseed farmers.",
#             "publishedAt": "2023-01-11T15:39:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India to halt duty free soyoil imports from April 1 - Reuters",
#             "url": "https://www.reuters.com/markets/commodities/india-halt-duty-free-soyoil-imports-april-1-2023-01-11/",
#             "urlToImage": "https://www.reuters.com/resizer/QhX38oWR4eTNNlU7Q_ctJEn3xIU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/54EIGD7KUZJPHBPZ5N64T27AQM.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 24 (Reuters) - Blackstone (BX.N) is in talks to sell around half of its stake in India's largest real estate investment trust Embassy Office Parks (EMBA.NS) to private equity firm Bain Ca\u2026 [+3438 chars]",
#             "description": "Blackstone <a href=\"https://www.reuters.com/companies/BX.N\" target=\"_blank\">(BX.N)</a> is in talks to sell around half of its stake in India's largest real estate investment trust Embassy Office Parks <a href=\"https://www.reuters.com/companies/EMBA.NS\" target\u2026",
#             "publishedAt": "2023-01-24T06:39:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Exclusive: Blackstone in talks with Bain to sell $480 mln stake in top ... - Reuters",
#             "url": "https://www.reuters.com/markets/deals/blackstone-talks-with-bain-sell-480-mln-stake-top-indian-reit-sources-2023-01-24/",
#             "urlToImage": "https://www.reuters.com/resizer/-MB__tFE5Hcygxr5vVpP5NY78h4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/IJ5WNOSWEVMVHBAJ64GJKCAQHA.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 18 (Reuters) - Indias Shree Cement (SHCM.NS) plans to raise funds selling commercial papers maturing in two months, three merchant bankers said on Wednesday.\r\nThe company will offer a yie\u2026 [+302 chars]",
#             "description": "India\u2019s Shree Cement <a href=\"https://www.reuters.com/companies/SHCM.NS\" target=\"_blank\">(SHCM.NS)</a> plans to raise funds selling commercial papers maturing in two months, three merchant bankers said on Wednesday.",
#             "publishedAt": "2023-01-18T09:10:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue Shree Cement to issue 2-month CP - traders - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-new-issue-shree-cement-issue-2-month-cp-traders-2023-01-18/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 20 (Reuters) - India's Birla Group Holdings plans to raise funds by selling commercial papers maturing in three months, three merchant bankers said on Thursday.\r\nThe company will offer a \u2026 [+312 chars]",
#             "description": "India's Birla Group Holdings plans to raise funds by selling commercial papers maturing in three months, three merchant bankers said on Thursday.",
#             "publishedAt": "2023-01-20T06:08:07Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue Birla Group Holdings to issue 3-month CP - traders - Reuters",
#             "url": "https://www.reuters.com/markets/asia/india-new-issue-birla-group-holdings-issue-3-month-cp-traders-2023-01-20/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 13 (Reuters) - Indian gold futures hit a record high on Friday, tracking gains in overseas market, but the price rise dampened demand in the world's second biggest consumer of the preciou\u2026 [+295 chars]",
#             "description": "Indian gold futures hit a record high on Friday, tracking gains in overseas market, but the price rise dampened demand in the world's second biggest consumer of the precious metal, dealers said.",
#             "publishedAt": "2023-01-13T09:00:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Indian gold prices hit record high, dampening demand -dealers - Reuters.com",
#             "url": "https://www.reuters.com/markets/commodities/indian-gold-prices-hit-record-high-dampening-demand-dealers-2023-01-13/",
#             "urlToImage": "https://www.reuters.com/resizer/xLsdLd6qJ8-o0yaEYGhxSEbGrxg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/AYP65QOVWBJKFGX366OTS7YSYQ.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 19 (Reuters) - India's Housing Development Finance Corp (HDFC.NS) plans to raise funds by issuing commercial papers maturing in one year, three merchant bankers said on Thursday.\r\nThe non\u2026 [+342 chars]",
#             "description": "India's Housing Development Finance Corp <a href=\"https://www.reuters.com/companies/HDFC.NS\" target=\"_blank\">(HDFC.NS)</a> plans to raise funds by issuing commercial papers maturing in one year, three merchant bankers said on Thursday.",
#             "publishedAt": "2023-01-19T07:09:52Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue HDFC to issue 1-year CP - traders - Reuters",
#             "url": "https://www.reuters.com/business/finance/india-new-issue-hdfc-issue-1-year-cp-traders-2023-01-19/",
#             "urlToImage": "https://www.reuters.com/resizer/eJWydrZR6IS1EenySqVnQcnr_AI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I6YB3PR62BLXBMRESNKBEXQP7Q.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 24 (Reuters) - Indian gold futures hit a fresh all-time high on Tuesday, tracking gains in overseas markets and a depreciation in the rupee currency, but the surge dampened demand in the \u2026 [+308 chars]",
#             "description": "Indian gold futures hit a fresh all-time high on Tuesday, tracking gains in overseas markets and a depreciation in the rupee currency, but the surge dampened demand in the world's second biggest consumer of the precious metal, dealers said.",
#             "publishedAt": "2023-01-24T04:54:56Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Indian gold prices hit record high, curtail demand -dealers - Reuters India",
#             "url": "https://www.reuters.com/world/india/indian-gold-prices-hit-record-high-curtail-demand-dealers-2023-01-24/",
#             "urlToImage": "https://www.reuters.com/resizer/f2L7F4xfBsdsr30ipR5FNKkHB-g=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/L3TB76NHUBJTPOYFOZVXEME4IU.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 25 (Reuters) - The Indian rupee rose against the U.S. currency on Wednesday, helped by likely dollar inflows and gains in most major Asian peers.\r\nThe rupee last traded at 81.59 per U.S. \u2026 [+1552 chars]",
#             "description": "The Indian rupee rose against the U.S. currency on Wednesday, helped by likely dollar inflows and gains in most major Asian peers.",
#             "publishedAt": "2023-01-25T10:27:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee rises on likely dollar inflows, gains in Asian ... - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-rises-likely-dollar-inflows-gains-asian-peers-2023-01-25/",
#             "urlToImage": "https://www.reuters.com/resizer/eQsj3ASBfvbyK49DGQtuhVWa1tc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WAAW5TV62RLNHNIKJLQPCTMEYU.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Feb 1 (Reuters) - The Indian rupee was trading marginally higher against the dollar on Wednesday ahead of the Union budget and the U.S. Federal Reserve policy decision.\r\nThe rupee was quoting\u2026 [+1654 chars]",
#             "description": "The Indian rupee was trading marginally higher against the dollar on Wednesday ahead of the Union budget and the U.S. Federal Reserve policy decision.",
#             "publishedAt": "2023-02-01T05:27:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee higher before budget, but risks seen on more ... - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-higher-before-budget-risks-seen-more-weakness-2023-02-01/",
#             "urlToImage": "https://www.reuters.com/resizer/7ZwICFAaVmjcLPF6ZqV0N4fklzs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JBY37H3GENJKRM56UH5ZOKGNSQ.jpg"
#         },
#         {
#             "author": null,
#             "content": "NEW DELHI, Jan 25 (Reuters) - The world's most affluent cricket board, India, got further richer by $572.72 million after unveiling five franchises for an Indian Premier League-style T20 tournament f\u2026 [+1673 chars]",
#             "description": "The world's most affluent cricket board, India, got further richer by $572.72 million after unveiling five franchises for an Indian Premier League-style T20 tournament for the women on Wednesday.",
#             "publishedAt": "2023-01-25T11:21:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Women's IPL franchises fetch $572 million for Indian board - Reuters",
#             "url": "https://www.reuters.com/lifestyle/sports/womens-ipl-franchises-fetch-572-million-indian-board-2023-01-25/",
#             "urlToImage": "https://www.reuters.com/resizer/LWHFB6n8KixeLssWo3PraaxrBLA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RYYA6ECBE5ICXLYYO2AXJP3XKI.jpg"
#         },
#         {
#             "author": null,
#             "content": "BENGALURU, Jan 31 (Reuters) - Century Textiles and Industries Ltd (CNTY.NS), the flagship company of India's Aditya Birla Group, reported a 38% drop in third-quarter profit on Tuesday, due to weaknes\u2026 [+1407 chars]",
#             "description": "Century Textiles and Industries Ltd <a href=\"https://www.reuters.com/companies/CNTY.NS\" target=\"_blank\">(CNTY.NS)</a>, the flagship company of India's Aditya Birla Group, reported a 38% drop in third-quarter profit on Tuesday, due to weakness in its textile b\u2026",
#             "publishedAt": "2023-01-31T09:18:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's Century Textiles Q3 profit drops as subdued textile business ... - Reuters India",
#             "url": "https://www.reuters.com/world/india/indias-century-textiles-q3-profit-drops-subdued-textile-business-weighs-2023-01-31/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": "Annesha Ghosh",
#             "content": "What is the Womens Premier League (WPL)?\r\nDescribed variously by a wide cross-section of stakeholders in cricket as a revolution in the womens game and a game-changer, the WPL is an Indian domestic T\u2026 [+6015 chars]",
#             "description": "The inaugural WPL in March is shaping as the richest in women\u2019s sport. As the game\u2019s stars gather for the US$572m tournament in India, here\u2019s how it works, who\u2019s playing and why it will turbo-boost cricketDescribed variously by a wide cross-section of stakeho\u2026",
#             "publishedAt": "2023-02-03T00:34:42Z",
#             "source": {
#                 "id": null,
#                 "name": "The Guardian"
#             },
#             "title": "\u2018Game changer\u2019: why the Women\u2019s Premier League is a revolution for players and fans",
#             "url": "https://www.theguardian.com/sport/2023/feb/03/game-changer-why-the-womens-premier-league-is-a-revolution-for-players-and-fans",
#             "urlToImage": "https://i.guim.co.uk/img/media/b25580117edc492931b459a46ac95c5499e5279d/0_66_2461_1477/master/2461.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=6a3ef02c335643e4cfc647d304856a39"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 30 (Reuters) - India's annual pre-budget economic survey is likely to peg GDP growth at 6-6.8% for 2023-24, according to a source.\r\nThe government survey is likely to say that growth is s\u2026 [+313 chars]",
#             "description": "India's annual pre-budget economic survey is likely to peg GDP growth at 6-6.8% for 2023-24, according to a source.",
#             "publishedAt": "2023-01-30T16:27:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Exclusive: India economic survey likely to peg 2023-24 growth at 6 ... - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-economic-survey-likely-peg-2023-24-growth-6-68-source-2023-01-30/",
#             "urlToImage": "https://www.reuters.com/resizer/xCC3pQgWbtRfZPkq9y-3DDdoEl0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RPKLPW7K3NPOTFV724UFUEERZQ.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 19 (Reuters) - India's Bank of Maharashtra (BMBK.NS) plans to raise funds through certificates of deposit maturing in three months, three merchant bankers said on Thursday.\r\nThe state-run\u2026 [+363 chars]",
#             "description": "India's Bank of Maharashtra <a href=\"https://www.reuters.com/companies/BMBK.NS\" target=\"_blank\">(BMBK.NS)</a> plans to raise funds through certificates of deposit maturing in three months, three merchant bankers said on Thursday.",
#             "publishedAt": "2023-01-19T04:32:19Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue Bank of Maharashtra to issue 3-month CD - traders - Reuters.com",
#             "url": "https://www.reuters.com/markets/asia/india-new-issue-bank-maharashtra-issue-3-month-cd-traders-2023-01-19/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "Jan 12 (Reuters) - India's annual retail inflation in December edged down from the previous month and remained within the central bank's comfort zone as the rate of food price rises continued its dow\u2026 [+7201 chars]",
#             "description": "India's annual <a href=\"/world/india/indias-december-retail-inflation-eases-572-yy-2023-01-12/\">retail inflation in December edged down</a> from the previous month and remained within the central bank's comfort zone as the rate of food price rises continued i\u2026",
#             "publishedAt": "2023-01-12T13:03:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "VIEW India's Dec retail inflation eases to 5.72% y/y - Reuters India",
#             "url": "https://www.reuters.com/world/india/view-indias-dec-retail-inflation-eases-572-yy-2023-01-12/",
#             "urlToImage": "https://www.reuters.com/resizer/1BKLrZErtnRjKO90yrc5AJibqeI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KCGEYNHTG5JGLOPLGIMLQM3EGI.jpg"
#         },
#         {
#             "author": null,
#             "content": "HONG KONG/MUMBAI, Jan 31 (Reuters Breakingviews) - India is making its way onto global investors maps. How the countrys financial authorities tackle the $65 billion selloff at Gautam Adanis eponymous\u2026 [+3989 chars]",
#             "description": "India is making its way onto global investors\u2019 maps. How the country\u2019s financial authorities tackle the $65 billion selloff at Gautam Adani\u2019s eponymous infrastructure empire following a <a href=\"https://nam02.safelinks.protection.outlook.com/?url=https%3A%2F%\u2026",
#             "publishedAt": "2023-01-31T02:08:12Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Breakingviews - Adani re-ups India's emerging market risk - Reuters",
#             "url": "https://www.reuters.com/breakingviews/adani-re-ups-indias-emerging-market-risk-2023-01-31/",
#             "urlToImage": "https://www.reuters.com/resizer/k0Q1blI0Ol2fhkff7uBzB7Wn9S4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/L7ARSX46SBKZ3DS6OHVKGXMD3Y.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 19 (Reuters) - The Indian rupee is likely to weaken at open against the U.S. dollar on Thursday as mounting global growth concerns prompted investors to exit risk assets.\r\nThe rupee is ti\u2026 [+2374 chars]",
#             "description": "The Indian rupee is likely to weaken at open against the U.S. dollar on Thursday as mounting global growth concerns prompted investors to exit risk assets.",
#             "publishedAt": "2023-01-19T02:58:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee seen lower as growth fears hit risk sentiment - Reuters.com",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-seen-lower-growth-fears-hit-risk-sentiment-2023-01-19/",
#             "urlToImage": "https://www.reuters.com/resizer/OI2aozAvcPPJri7CI-yIQPtCAQA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XBWLEKZZSVNRVCIZ5BIX5YGC7I.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 17 (Reuters) - The Indian rupee was expected to open lower against the U.S. dollar on Tuesday, tracking losses in Asian peers and on dwindling upside momentum, traders said.\r\nThe rupee wa\u2026 [+2434 chars]",
#             "description": "The Indian rupee was expected to open lower against the U.S. dollar on Tuesday, tracking losses in Asian peers and on dwindling upside momentum, traders said.",
#             "publishedAt": "2023-01-17T03:09:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee likely to fall on weak Asia FX, waning ... - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-likely-fall-weak-asia-fx-waning-momentum-2023-01-17/",
#             "urlToImage": "https://www.reuters.com/resizer/38YeaJWTXpQjYm3PyxyA39BRbMg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EMUQXHXFFNL5NLUF3PKE4PZWQA.jpg"
#         },
#         {
#             "author": null,
#             "content": "Jan 27 (Reuters) - Physical gold dealers in India offered the steepest discounts in 10 months this week to lure customers, as a sharp rally in local prices squeezed demand in the world's second-bigge\u2026 [+1955 chars]",
#             "description": "Physical gold dealers in India offered the steepest discounts in 10 months this week to lure customers, as a sharp rally in local prices squeezed demand in the world's second-biggest bullion consumer.",
#             "publishedAt": "2023-01-27T12:47:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Asia Gold Indian dealers offer hefty discounts as high prices dent sales - Reuters",
#             "url": "https://www.reuters.com/markets/commodities/asia-gold-indian-dealers-offer-hefty-discounts-high-prices-dent-sales-2023-01-27/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Feb 2 (Reuters) - India's January palm oil imports fell 31% from a month ago to their lowest in months as a narrowing discount to rival oils prompted refiners to increase purchases of soybean\u2026 [+2049 chars]",
#             "description": "India's January palm oil imports fell 31% from a month ago to their lowest in months as a narrowing discount to rival oils prompted refiners to increase purchases of soybean and sunflower oils, five dealers told Reuters on Thursday.",
#             "publishedAt": "2023-02-02T07:46:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Top palm oil buyer India's Jan imports fall to six-month low -dealers - Reuters",
#             "url": "https://www.reuters.com/markets/commodities/top-palm-oil-buyer-indias-jan-imports-fall-six-month-low-dealers-2023-02-02/",
#             "urlToImage": "https://www.reuters.com/resizer/ykL1XO_5TbExNlkBJsbIDAYQF6c=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WGS465SU55MGNNDRB63RLFGXM4.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 23 (Reuters) - India's Housing Development Finance Corp (HDFC.NS) plans to raise at least 30 billion rupees ($370.5 million) through the sale of bonds maturing in 10 years, three merchant\u2026 [+736 chars]",
#             "description": "India's Housing Development Finance Corp <a href=\"https://www.reuters.com/companies/HDFC.NS\" target=\"_blank\">(HDFC.NS)</a> plans to raise at least 30 billion rupees ($370.5 million) through the sale of bonds maturing in 10 years, three merchant bankers said o\u2026",
#             "publishedAt": "2023-01-23T02:59:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue HDFC to issue 10-year bonds - traders - Reuters",
#             "url": "https://www.reuters.com/markets/asia/india-new-issue-hdfc-issue-10-year-bonds-traders-2023-01-23/",
#             "urlToImage": "https://www.reuters.com/resizer/eJWydrZR6IS1EenySqVnQcnr_AI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I6YB3PR62BLXBMRESNKBEXQP7Q.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 23 (Reuters) - India's central bank likely bought dollars via state-run banks to prevent the rupee from appreciating significantly above the 81 psychological level, three traders told Reu\u2026 [+533 chars]",
#             "description": "India's central bank likely bought dollars via state-run banks to prevent the rupee from appreciating significantly above the 81 psychological level, three traders told Reuters.",
#             "publishedAt": "2023-01-23T05:22:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's cenbank likely buying dollar after rupee rose above 81/USD ... - Reuters",
#             "url": "https://www.reuters.com/markets/asia/indias-cenbank-likely-buying-dollar-after-rupee-rose-above-81usd-traders-2023-01-23/",
#             "urlToImage": "https://www.reuters.com/resizer/N7RzuWcXYUyoZLbgRRpCObGRARY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/U57OPQ7D6NJL5MGH5GEKJR65OQ.jpg"
#         },
#         {
#             "author": null,
#             "content": "LONDON, Jan 27 (Reuters) - Dollar bonds issued by entities of India's Adani Group tumbled on Friday as a scathing report by a U.S. short seller triggered a rout in the conglomerate's listed firms.\r\nT\u2026 [+627 chars]",
#             "description": "Dollar bonds issued by entities of India's Adani Group tumbled on Friday as a scathing report by a U.S. short seller triggered <a href=\"/business/indias-adani-kicks-off-245-bln-share-sale-while-under-short-seller-attack-2023-01-27/\">a rout</a> in the conglome\u2026",
#             "publishedAt": "2023-01-27T09:06:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's Adani dollar bonds hit lowest since November - Reuters",
#             "url": "https://www.reuters.com/business/indias-adani-dollar-bonds-hit-lowest-since-november-2023-01-27/",
#             "urlToImage": "https://www.reuters.com/resizer/87yfLsQ_EDbSZxyRDEW6190GcG8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5O5Y2SSSDZIEFFMXBNYWTLRUO4.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 18 (Reuters) - The Indian rupee is likely to inch up against the dollar on Wednesday, helped by the decline in the USD/INR non-deliverable forwards (NDF).\r\nThe rupee is expected to open a\u2026 [+1870 chars]",
#             "description": "The Indian rupee is likely to inch up against the dollar on Wednesday, helped by the decline in the USD/INR non-deliverable forwards (NDF).",
#             "publishedAt": "2023-01-18T03:04:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee to open higher tracking NDFs, BoJ in focus - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-open-higher-tracking-ndfs-boj-focus-2023-01-18/",
#             "urlToImage": "https://www.reuters.com/resizer/eQsj3ASBfvbyK49DGQtuhVWa1tc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WAAW5TV62RLNHNIKJLQPCTMEYU.jpg"
#         },
#         {
#             "author": null,
#             "content": "BENGALURU, Jan 12 (Reuters) - China's Alibaba Group (9988.HK) sold a 3.1% stake in Indian digital payments firm Paytm (PAYT.NS) worth $125 million through a block deal on Thursday, a source with dire\u2026 [+546 chars]",
#             "description": "China's Alibaba Group <a href=\"https://www.reuters.com/companies/9988.HK\" target=\"_blank\">(9988.HK)</a> sold a 3.1% stake in Indian digital payments firm Paytm <a href=\"https://www.reuters.com/companies/PAYT.NS\" target=\"_blank\">(PAYT.NS)</a> worth $125 millio\u2026",
#             "publishedAt": "2023-01-12T09:19:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Alibaba sells Paytm stake worth $125 mln via block deal - source - Reuters",
#             "url": "https://www.reuters.com/markets/deals/alibaba-sells-paytm-stake-worth-125-mln-via-block-deal-source-2023-01-12/",
#             "urlToImage": "https://www.reuters.com/resizer/BuCaI_o8ycpAeE6ni9ZF7Ki7duc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6B42PXP6K5JOVPOU4VJUBLL5CI.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Feb 1 (Reuters) - The Indian government will spend 10 trillion rupees ($122.3 billion) on longer term capital expenditure in 2023/24, extending a strategy adopted to revive growth in the afte\u2026 [+658 chars]",
#             "description": "The Indian government will spend 10 trillion rupees ($122.3 billion) on longer term capital expenditure in 2023/24, extending a strategy adopted to revive growth in the aftermath of the COVID crisis.",
#             "publishedAt": "2023-02-01T06:09:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India 2023/24 budget raises capex spend to 10 trillion rupees - Reuters",
#             "url": "https://www.reuters.com/world/india/india-202324-budget-raises-capex-spend-10-trillion-rupees-2023-02-01/",
#             "urlToImage": "https://www.reuters.com/resizer/-zn8FQsER9rt2JEHg89pTuDg7Ko=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/AGGZLFDJZFKD3HWUSHYMMQYWCM.jpg"
#         },
#         {
#             "author": null,
#             "content": "NEW DELHI/MUMBAI, Feb 2 (Reuters) - India's central bank has asked local banks for details of their exposure to the Adani group of companies, government and banking sources said on Thursday.\r\nThe Res\u2026 [+560 chars]",
#             "description": "India's central bank has asked local banks for details of their exposure to the Adani group of companies, government and banking sources said on Thursday.",
#             "publishedAt": "2023-02-02T04:59:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India cenbank asks country's banks for details of exposure to Adani ... - Reuters",
#             "url": "https://www.reuters.com/business/finance/india-cenbank-asks-countrys-banks-details-exposure-adani-group-sources-2023-02-02/",
#             "urlToImage": "https://www.reuters.com/resizer/BLpyc7Uq8cKY2A_fwiMsN_2W78Y=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/D72N5IJJZFJWJAHXT2FB7STCAA.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 10 (Reuters) - The Indian rupee is poised to open higher against the U.S. dollar on Tuesday, tracking more broad losses on the greenback, as traders bet that the Federal Reserve could opt\u2026 [+2120 chars]",
#             "description": "The Indian rupee is poised to open higher against the U.S. dollar on Tuesday, tracking more broad losses on the greenback, as traders bet that the Federal Reserve could opt for smaller interest rate hikes.",
#             "publishedAt": "2023-01-10T02:58:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee may firm on smaller Fed rate hike bets; dollar ... - Reuters.com",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-may-firm-smaller-fed-rate-hike-bets-dollar-hits-7-month-low-2023-01-10/",
#             "urlToImage": "https://www.reuters.com/resizer/iLaWKme94I4jjfSPGYMylijfyjM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/R4VARFLPD5PT3BKJOV7P4CK67Y.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI/NEW DELHI, Jan 30 (Reuters) - Wheat prices in India, the world's biggest consumer of the grain after China, have dropped nearly 13% from record highs since the government offer last week of 3 \u2026 [+1992 chars]",
#             "description": "Wheat prices in India, the world's biggest consumer of the grain after China, have dropped nearly 13% from record highs since the government offer last week of 3 million tonnes to bulk consumers such as flour millers.",
#             "publishedAt": "2023-01-30T14:35:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Indian wheat prices drop after Modi releases grain for flour millers - Reuters India",
#             "url": "https://www.reuters.com/world/india/indian-wheat-prices-drop-after-modi-releases-grain-flour-millers-2023-01-30/",
#             "urlToImage": "https://www.reuters.com/resizer/B-VJuYZCrsuatCehWkONGB-jjkw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/A42OZK7JRBO53ISYRCYG5CIOJ4.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 17 (Reuters) - India is likely to produce 34.3 million tonnes of sugar in 2022/23, down 4% from the previous forecast, as sugar cane yields in key producing states fell due to adverse wea\u2026 [+601 chars]",
#             "description": "India is likely to produce 34.3 million tonnes of sugar in 2022/23, down 4% from the previous forecast, as sugar cane yields in key producing states fell due to adverse weather, a senior industry official told Reuters.",
#             "publishedAt": "2023-01-17T06:53:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India 2022/23 sugar output to fall on adverse weather -industry official - Reuters",
#             "url": "https://www.reuters.com/markets/commodities/india-202223-sugar-output-fall-adverse-weather-industry-official-2023-01-17/",
#             "urlToImage": "https://www.reuters.com/resizer/4MM99uCNOjde92AQFKMxVQ4p0Hc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/24LT7LBFFNPUXNW4WRVIMNO5EU.jpg"
#         },
#         {
#             "author": null,
#             "content": "SINGAPORE, Jan 31 (Reuters) - Dollar bonds issued by entities of India's Adani Group rose on Tuesday after a sharp dive in the past few days following a scathing report by a U.S. short seller that tr\u2026 [+576 chars]",
#             "description": "Dollar bonds issued by entities of India's Adani Group rose on Tuesday after a sharp dive in the past few days following a scathing report by a U.S. short seller that triggered a rout in the conglomerate's listed firms.",
#             "publishedAt": "2023-01-31T02:49:31Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's Adani dollar bonds edge higher after sharp dive - Reuters",
#             "url": "https://www.reuters.com/markets/rates-bonds/indias-adani-dollar-bonds-edge-higher-after-sharp-dive-2023-01-31/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 23 (Reuters) - India's Trust Investment Advisors plans to raise at least 500 million rupees ($6.18 million) through bonds maturing in seven years, three merchant bankers said on Monday.\r\n\u2026 [+527 chars]",
#             "description": "India's Trust Investment Advisors plans to raise at least 500 million rupees ($6.18 million) through bonds maturing in seven years, three merchant bankers said on Monday.",
#             "publishedAt": "2023-01-23T04:13:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue Trust Investment Advisors to issue 7-year bond ... - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-new-issue-trust-investment-advisors-issue-7-year-bond-traders-2023-01-23/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 24 (Reuters) - India's Kotak Mahindra Investments plans to raise at least 750 million rupees ($9.19 million) through two bonds, one maturing in April 2026 and the other in May 2026, three\u2026 [+740 chars]",
#             "description": "India's Kotak Mahindra Investments plans to raise at least 750 million rupees ($9.19 million) through two bonds, one maturing in April 2026 and the other in May 2026, three merchant bankers said on Tuesday.",
#             "publishedAt": "2023-01-24T03:56:22Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue Kotak Mahindra Investments to issue multiple-tenor ... - Reuters",
#             "url": "https://www.reuters.com/markets/asia/india-new-issue-kotak-mahindra-investments-issue-multiple-tenor-bonds-traders-2023-01-24/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": "Hakai Magazine",
#             "content": "Article body copy\r\nIt is not yet 8:00 a.m., and the sun is already fierce on a small rowboat anchored a kilometer from the eastern banks of Thane Creek, an inlet separating the island city of Mumbai \u2026 [+17894 chars]",
#             "description": "Despite pressure from development, flamingos seem to be thriving on the shores of one of the world\u2019s most populous cities, and local people are becoming protective of the birds and their habitat.",
#             "publishedAt": "2023-01-19T04:14:44Z",
#             "source": {
#                 "id": null,
#                 "name": "Hakaimagazine.com"
#             },
#             "title": "Mumbai embraces its booming flamingo population",
#             "url": "https://hakaimagazine.com/features/mumbai-embraces-its-booming-flamingo-population/",
#             "urlToImage": "https://hakaimagazine.com/wp-content/uploads/facebook-mumbai-flamingos.jpg"
#         },
#         {
#             "author": "Tim Hardwick",
#             "content": "Apple has begun hiring staff for its first flagship stores in India, reports The Financial Times. Job listings for 12 store worker roles have been found in \"various locations\" throughout the country,\u2026 [+1951 chars]",
#             "description": "Apple has begun hiring staff for its first flagship stores in India, reports The Financial Times. Job listings for 12 store worker roles have been found in \"various locations\" throughout the country, indicating that Apple is almost ready to establish a retail\u2026",
#             "publishedAt": "2023-01-09T09:27:48Z",
#             "source": {
#                 "id": null,
#                 "name": "MacRumors"
#             },
#             "title": "Apple Hires Staff Ahead of First Retail Stores Opening in India",
#             "url": "https://www.macrumors.com/2023/01/09/apple-hires-retail-store-staff-india/",
#             "urlToImage": "https://images.macrumors.com/t/yQIJcb8Y-avkal6pF9GMKjehEcY=/2304x/article-new/2020/08/apple-india.jpg"
#         },
#         {
#             "author": "Isaac Schultz",
#             "content": "A team of paleontologists in India have given 256 fossilized dinosaur eggs a close look, in hopes of better understanding how some of the largest known dinosaurs bred and hatched.\r\nThe eggs were foun\u2026 [+2879 chars]",
#             "description": "A team of paleontologists in India have given 256 fossilized dinosaur eggs a close look, in hopes of better understanding how some of the largest known dinosaurs bred and hatched.Read more...",
#             "publishedAt": "2023-01-18T19:13:00Z",
#             "source": {
#                 "id": null,
#                 "name": "Gizmodo.com"
#             },
#             "title": "Nearly 100 Titanosaur Nests, Complete With Fossilized Eggs, Found in India",
#             "url": "https://gizmodo.com/titanosaur-nests-eggs-fossils-found-india-1850001778",
#             "urlToImage": "https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/5f54a33789131852b989164ef5008ee1.png"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 18 (Reuters) - The Indian government bought back bonds maturing in 2024 from the Reserve Bank of India on Tuesday, while also issuing bonds maturing in 2032 worth a similar quantum, the c\u2026 [+888 chars]",
#             "description": "The Indian government bought back bonds maturing in 2024 from the Reserve Bank of India on Tuesday, while also issuing bonds maturing in 2032 worth a similar quantum, the central bank said on Wednesday.",
#             "publishedAt": "2023-01-18T22:07:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India govt switches bonds with cenbank in a cash-neutral deal - Reuters",
#             "url": "https://www.reuters.com/markets/rates-bonds/india-govt-switches-bonds-with-cenbank-cash-neutral-deal-2023-01-18/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "BENGALURU, Jan 20 (Reuters) - HDFC Life Insurance Co (HDFL.NS) reported a 15% rise in third-quarter profit on Friday, driven by higher income from premiums and its investments and said it expects to \u2026 [+1238 chars]",
#             "description": "HDFC Life Insurance Co <a href=\"https://www.reuters.com/companies/HDFL.NS\" target=\"_blank\">(HDFL.NS)</a> reported a 15% rise in third-quarter profit on Friday, driven by higher income from premiums and its investments and said it expects to sell more policies\u2026",
#             "publishedAt": "2023-01-20T09:23:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's HDFC Life reports 15% jump in Q3 profit as premiums climb - Reuters",
#             "url": "https://www.reuters.com/markets/asia/indias-hdfc-life-reports-15-jump-q3-profit-premiums-climb-2023-01-20/",
#             "urlToImage": "https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=127"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 20 (Reuters) - India's Housing Development Finance Corp (HDFC.NS) (HDFC) will return to bond market after a gap of two months, three merchant bankers said on Friday.\r\nThe company plans to\u2026 [+829 chars]",
#             "description": "India's Housing Development Finance Corp <a href=\"https://www.reuters.com/companies/HDFC.NS\" target=\"_blank\">(HDFC.NS)</a> (HDFC) will return to bond market after a gap of two months, three merchant bankers said on Friday.",
#             "publishedAt": "2023-01-20T05:46:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India New Issue HDFC likely to raise at least 30 bln rupees via ... - Reuters",
#             "url": "https://www.reuters.com/markets/asia/india-new-issue-hdfc-likely-raise-least-30-bln-rupees-via-bonds-next-week-2023-01-20/",
#             "urlToImage": "https://www.reuters.com/resizer/eJWydrZR6IS1EenySqVnQcnr_AI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/I6YB3PR62BLXBMRESNKBEXQP7Q.jpg"
#         },
#         {
#             "author": null,
#             "content": "Jan 17 (Reuters) - India's local authorities seized four aircraft belonging to Jet Airways (JET.NS) for non-payment of gratuity dues, CNBC-TV18 reported on Tuesday, citing sources.\r\nThe Mumbai distri\u2026 [+874 chars]",
#             "description": "India's local authorities seized four aircraft belonging to Jet Airways <a href=\"https://www.reuters.com/companies/JET.NS\" target=\"_blank\">(JET.NS)</a> for non-payment of gratuity dues, CNBC-TV18 reported on Tuesday, citing sources.",
#             "publishedAt": "2023-01-17T18:00:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "City officials seize four aircraft of India's Jet Airways, CNBC-TV18 ... - Reuters",
#             "url": "https://www.reuters.com/business/aerospace-defense/city-officials-seize-four-aircraft-indias-jet-airways-cnbc-tv18-reports-2023-01-17/",
#             "urlToImage": "https://www.reuters.com/resizer/lc-3BiPLJ01dfJlJf8jd8vxicWQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7LEHYCMDWZKU3B6FPKLDYVNXFE.jpg"
#         },
#         {
#             "author": null,
# ...
#             "description": "The Indian rupee edged higher on Thursday, as risk assets jumped after the U.S. Federal Reserve meeting, but gains in the local currency were capped as equities remained jittery.",
#             "publishedAt": "2023-02-02T08:20:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Rupee inches up as risk assets rally, gains capped by weak equities - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-inches-up-risk-assets-rally-gains-capped-by-weak-equities-2023-02-02/",
#             "urlToImage": "https://www.reuters.com/resizer/7ZwICFAaVmjcLPF6ZqV0N4fklzs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JBY37H3GENJKRM56UH5ZOKGNSQ.jpg"
#         },
#         {
#             "author": "Jon Astbury",
#             "content": "Flowing \"calligraphic forms\" made from sheets of perforated metal define this renovation of a 1980s office block in Mumbai, designed by local practice Studio Symbiosis.\r\nOriginally a six-storey struc\u2026 [+3039 chars]",
#             "description": "Flowing \"calligraphic forms\" made from sheets of perforated metal define this renovation of a 1980s office block in Mumbai, designed by local practice Studio Symbiosis. Originally a six-storey structure, the building houses the offices of the I Dudhwala Real \u2026",
#             "publishedAt": "2023-01-13T11:00:50Z",
#             "source": {
#                 "id": null,
#                 "name": "Dezeen"
#             },
#             "title": "Studio Symbiosis extends and renovates Mumbai office block with flowing metal forms",
#             "url": "https://www.dezeen.com/2023/01/13/studio-symbiosis-id-origins-mumbai-office-renovation-extension/",
#             "urlToImage": "https://static.dezeen.com/uploads/2023/01/studio-symbiosis-mumbai-office-renovation-extension-hero-2-600x600.jpg"
#         },
#         {
#             "author": "zsalfiti@insider.com (Zinya Salfiti)",
#             "content": "Indian industrialist Gautam Adani is no longer Asia's richest person as a rout in his conglomerate's stocks intensified, after a bombshell report by short-seller Hindenburg Research.\r\nHe now has an e\u2026 [+1814 chars]",
#             "description": "With an estimated net worth of $74.7 billion, Adani now ranks as the world's 15th richest person on Forbes' billionaire list.",
#             "publishedAt": "2023-02-01T18:04:04Z",
#             "source": {
#                 "id": "business-insider",
#                 "name": "Business Insider"
#             },
#             "title": "Gautam Adani isn't Asia's richest person any more after losing over $50 billion as his companies' stock rout deepens",
#             "url": "https://markets.businessinsider.com/news/stocks/adani-billionaire-richest-no-more-asia-stocks-tank-short-seller-2023-2",
#             "urlToImage": "https://i.insider.com/63da3de40a08ae0018a64893?width=1200&format=jpeg"
#         },
#         {
#             "author": null,
#             "content": "NEW DELHI/MUMBAI, Jan 13 (Reuters) - India is preparing a stepped-up deficit reduction plan in its annual budget due out next month, two government officials said, holding fast to fiscal targets that\u2026 [+3888 chars]",
#             "description": "India is preparing a stepped-up deficit reduction plan in its annual budget due out next month, two government officials said, holding fast to fiscal targets that will require deep spending cuts and could pose fresh risks in a slowing global economy.",
#             "publishedAt": "2023-01-13T10:26:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India to speed up deficit reduction as fiscal target looms - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-speed-up-deficit-reduction-fiscal-target-looms-2023-01-13/",
#             "urlToImage": "https://www.reuters.com/resizer/QKjbnqWZjyF7jL1zPp0ILoGG1Ww=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/4ZYZGGGJ3JOD3DDBR2A7VHQ3FI.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI/NEW DELHI, Jan 10 (Reuters) - India's wheat production is set to jump to a record after all-time high prices prompted farmers to expand planting areas with high-yielding varieties and good wea\u2026 [+2256 chars]",
#             "description": "India's wheat production is set to jump to a record after all-time high prices prompted farmers to expand planting areas with high-yielding varieties and good weather conditions, scientists and traders told Reuters.",
#             "publishedAt": "2023-01-10T07:56:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India wheat harvest could hit record on higher planting area ... - Reuters",
#             "url": "https://www.reuters.com/markets/commodities/india-wheat-harvest-could-hit-record-higher-planting-area-favourable-weather-2023-01-10/",
#             "urlToImage": "https://www.reuters.com/resizer/GQn9BcuyW_w7_ZwpoiTBFLkFYrA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ANFYODSPTZKLZIJJN2BNVRRRJM.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 11 (Reuters) - The Indian rupee may open slightly higher against the dollar on Wednesday, building on the previous day's momentum when it managed to move above important resistance levels\u2026 [+2293 chars]",
#             "description": "The Indian rupee may open slightly higher against the dollar on Wednesday, building on the previous day's momentum when it managed to move above important resistance levels, traders said.",
#             "publishedAt": "2023-01-11T02:50:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "INDIA RUPEE Rupee may open higher after moving above key levels - Reuters",
#             "url": "https://www.reuters.com/markets/currencies/india-rupee-rupee-may-open-higher-after-moving-above-key-levels-2023-01-11/",
#             "urlToImage": "https://www.reuters.com/resizer/38YeaJWTXpQjYm3PyxyA39BRbMg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/EMUQXHXFFNL5NLUF3PKE4PZWQA.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 25 (Reuters) - India has invited Pakistan's foreign minister to a meeting of the Shanghai Co-operation Organisation (SCO) that it is hosting in May, Indian media reported on Wednesday, si\u2026 [+2031 chars]",
#             "description": "India has invited Pakistan's foreign minister to a meeting of the Shanghai Co-operation Organisation (SCO) that it is hosting in May, Indian media reported on Wednesday, signalling a possible thaw in relations between the nuclear-armed rivals.",
#             "publishedAt": "2023-01-25T05:22:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India invites Pakistan's foreign minister for May meeting - media ... - Reuters",
#             "url": "https://www.reuters.com/world/asia-pacific/india-invites-pakistans-foreign-minister-may-meeting-media-reports-2023-01-25/",
#             "urlToImage": "https://www.reuters.com/resizer/I8SDdeWo2hcsKfeJMWcCLILtjy8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MJMWKCXQRFM47JR326Y6NXOIEA.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 13 (Reuters) - Core inflation in India is an area of concern and the Reserve Bank of India needs to be very vigilant of it, the bank's chief Shaktikanta Das said on Friday.\r\nIndia's annua\u2026 [+1999 chars]",
#             "description": "Core inflation in India is an area of concern and the Reserve Bank of India needs to be very vigilant of it, the bank's chief Shaktikanta Das said on Friday.",
#             "publishedAt": "2023-01-13T14:34:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India central bank chief calls for vigilance on high core inflation - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-central-bank-chief-calls-vigilance-high-core-inflation-2023-01-13/",
#             "urlToImage": "https://www.reuters.com/resizer/2JRw8IxOuqTdOhRqLpbhZozBDQg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2XAT6HOUXJPZBABX777LIJVIXE.jpg"
#         },
#         {
#             "author": null,
#             "content": "DAVOS, Switzerland, Jan 16 (Reuters) - Confidence among companies in their growth prospects has dropped the most since the 2007-08 global financial crisis due to rising inflation, macroeconomic volat\u2026 [+2543 chars]",
#             "description": "Confidence among companies in their growth prospects has dropped the most since the 2007-08 global financial crisis due to rising inflation, macroeconomic volatility and geopolitical conflicts, a survey by PricewaterhouseCoopers showed.",
#             "publishedAt": "2023-01-16T18:03:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Davos 2023: CEOs most gloomy on growth in more than a decade ... - Reuters.com",
#             "url": "https://www.reuters.com/technology/davos-2023-ceos-most-gloomy-growth-more-than-decade-pwc-survey-2023-01-16/",
#             "urlToImage": "https://www.reuters.com/resizer/lCgTkJJkbutwxAE24Jru-30vpkY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7RGUTHN2LBOTLN5YIOJCHE7U64.jpg"
#         },
#         {
#             "author": null,
#             "content": "MUMBAI, Jan 17 (Reuters) - The Indian central bank's discussion paper suggesting banks make provisions on bad loans using an expected credit loss (ECL) method could raise capital requirements for len\u2026 [+2179 chars]",
#             "description": "The Indian central bank's discussion paper suggesting banks make provisions on bad loans using an expected credit loss (ECL) method could raise capital requirements for lenders, analysts said.",
#             "publishedAt": "2023-01-17T03:54:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India cenbank's new proposal on loan loss provisions to raise bank ... - Reuters India",
#             "url": "https://www.reuters.com/world/india/india-cenbanks-new-proposal-loan-loss-provisions-raise-bank-capital-needs-2023-01-17/",
#             "urlToImage": "https://www.reuters.com/resizer/2YIPls8kDTQ4xVbMKU4FntuIilg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QDGQGGOTKZLXTO6GZ5UMYS6KC4.jpg"
#         },
#         {
#             "author": null,
#             "content": "DAVOS, Switzerland, Jan 18 (Reuters) - The collapse in the prices of digital assets over the past year will allow investors to focus on the \"true value\" of this new technology, the distributed ledger\u2026 [+1958 chars]",
#             "description": "The collapse in the prices of digital assets over the past year will allow investors to focus on the \"true value\" of this new technology, the distributed ledger and the smart contracts that can be built on them, former Reserve Bank of India Governor Raghuram \u2026",
#             "publishedAt": "2023-01-18T20:21:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "DAVOS 2023 Crypto collapse brings focus to digital assets' 'true ... - Reuters",
#             "url": "https://www.reuters.com/technology/davos-2023-crypto-collapse-brings-focus-digital-assets-true-value-ex-india-2023-01-18/",
#             "urlToImage": "https://www.reuters.com/resizer/OxnP7kt-Th_tZMxRko46eeSRMqo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/ELGH2Q3NCZMYVPLZNEZN3KTHXE.jpg"
#         },
#         {
#             "author": null,
#             "content": "DAVOS, Switzerland, Jan 20 (Reuters) - Holcim (HOLN.S) expects the U.S. Inflation Reduction Act (IRA) to provide strong momentum for its business in North America which is outperforming other regions\u2026 [+2591 chars]",
#             "description": "Holcim <a href=\"https://www.reuters.com/companies/HOLN.S\" target=\"_blank\">(HOLN.S)</a> expects the U.S. Inflation Reduction Act (IRA) to provide strong momentum for its business in North America which is outperforming other regions, the company's head of Euro\u2026",
#             "publishedAt": "2023-01-20T12:12:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Davos 2023 Holcim sees U.S. inflation act helping it in N.America - Reuters",
#             "url": "https://www.reuters.com/markets/us/davos-2023-holcim-sees-us-inflation-act-helping-it-namerica-2023-01-20/",
#             "urlToImage": "https://www.reuters.com/resizer/XGtWDIzkNlBee1lVrS1LRafFmAo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2J7L2U5ZS5J5RK4K4EEYU3YDNI.jpg"
#         }
#     ],
#     "status": "ok",
#     "totalResults": 6548
# }
#   source.id   source.name                            author  \
# 0  bbc-news      BBC News  https://www.facebook.com/bbcnews
# 1   reuters       Reuters                              None
# 2      None  The Guardian                  Karishma Luthria
# 3   reuters       Reuters                              None
# 4   reuters       Reuters                              None
#
#                                                title  \
# 0  Vistara: 'Unruly' passenger tied to seat in In...
# 1  Dollar bonds of India's Adani Group continue t...
# 2  My colleague said: ‘Just be yourself.’ It was ...
# 3  India to halt duty free soyoil imports from Ap...
# 4  Exclusive: Blackstone in talks with Bain to se...
#
#                                          description  \
# 0  The Italian woman, who was arrested on a compl...
# 1  Dollar bonds issued by entities of India's Ada...
# 2  In this series, Guardian writers share the bes...
# 3  India will halt duty free imports of crude soy...
# 4  Blackstone <a href="https://www.reuters.com/co...
#
#                                                  url  \
# 0  https://www.bbc.co.uk/news/world-asia-india-64...
# 1  https://www.reuters.com/markets/rates-bonds/do...
# 2  https://www.theguardian.com/lifeandstyle/2023/...
# 3  https://www.reuters.com/markets/commodities/in...
# 4  https://www.reuters.com/markets/deals/blacksto...
#
#                                           urlToImage           publishedAt  \
# 0  https://ichef.bbci.co.uk/news/1024/branded_new...  2023-01-31T09:23:49Z
# 1  https://www.reuters.com/resizer/JdNNuQGag_MApH...  2023-01-31T10:00:00Z
# 2  https://i.guim.co.uk/img/media/7e07216caa44d1e...  2023-01-09T14:00:19Z
# 3  https://www.reuters.com/resizer/QhX38oWR4eTNNl...  2023-01-11T15:39:00Z
# 4  https://www.reuters.com/resizer/-MB__tFE5Hcygx...  2023-01-24T06:39:00Z
#
#                                              content
# 0  The crew of an Indian airline tied an Italian ...
# 1  MUMBAI, Jan 31 (Reuters) - Dollar bonds issued...
# 2  A cliche, overused in movies and young adult n...
# 3  MUMBAI, Jan 11 (Reuters) - India will halt dut...
# 4  MUMBAI, Jan 24 (Reuters) - Blackstone (BX.N) i...
# Enter Location: pune
# C:\Users\Nilesh\AppData\Local\Temp\ipykernel_134728\2981409708.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = r"C:\Users\Nilesh\.cache\selenium\chromedriver.exe")
